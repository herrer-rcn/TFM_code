# %%
timestamps = array_dreta['UNIX_TIMESTAMP']
acc_x_values = array_dreta['ACC_X']
acc_y_values = array_dreta['ACC_Y']
acc_z_values = array_dreta['ACC_Z']

def find_closest_index(arr, target):
    return np.abs(arr - target).argmin()

fragments = []

# Fragmentar la señal alrededor de cada pico y plotear cada fragmento
for i, peak_index in enumerate(peaks):
    peak_time = timestamps[peak_index]
    start_time = peak_time - 1900
    end_time = peak_time + 1900

    start_index = find_closest_index(timestamps, start_time)
    end_index = find_closest_index(timestamps, end_time)
    
    fragment = array_dreta[start_index:end_index + 1]
    
    # Obtener las columnas de cada fragmento
    fragment_timestamps = fragment['UNIX_TIMESTAMP']
    fragment_acc_x = fragment['ACC_X']
    fragment_acc_y = fragment['ACC_Y']
    fragment_acc_z = fragment['ACC_Z']
    
    # Plotear el fragmento de ACC_Z
    plt.figure()
    plt.plot(fragment_acc_z)
    plt.title(f"Fragmento {i+1}")
    plt.xlabel("Índice")
    plt.ylabel("ACC_Z")
    plt.grid(True)
    plt.show()
    
    fragments.append(fragment)
    
# Directorio donde se guardarán los archivos CSV
directory = "C:/Users/Holacons/OneDrive - Vueling Airlines, S.A/Escritorio/TFM/fragmentos_tiempo"


if not os.path.exists(directory):
    os.makedirs(directory)

# Itera sobre los fragmentos y guárdalos como archivos CSV
for i, fragment in enumerate(fragments):
    # Nombre del archivo CSV
    filename = os.path.join(directory, f"derecha_J1_{i+1}.csv")
    
    # Guardar el fragmento como archivo CSV
    df_fragment = pd.DataFrame(fragment, columns=['UNIX_TIMESTAMP', 'ACC_X', 'ACC_Y', 'ACC_Z'])
    df_fragment.to_csv(filename, index=False)

# %%
# Suponiendo que 'array_dreta' es un ndarray que contiene las columnas 'UNIX_TIMESTAMP', 'ACC_X', 'ACC_Y' y 'ACC_Z'
timestamps = array_reves['UNIX_TIMESTAMP']
acc_x_values = array_reves['ACC_X']
acc_y_values = array_reves['ACC_Y']
acc_z_values = array_reves['ACC_Z']

def find_closest_index(arr, target):
    return np.abs(arr - target).argmin()

fragments = []

# Fragmentar la señal alrededor de cada pico y plotear cada fragmento
for i, peak_index in enumerate(peaks):
    peak_time = timestamps[peak_index]
    start_time = peak_time - 1900
    end_time = peak_time + 1900

    start_index = find_closest_index(timestamps, start_time)
    end_index = find_closest_index(timestamps, end_time)
    
    fragment = array_reves[start_index:end_index + 1]
    
    # Obtener las columnas de cada fragmento
    fragment_timestamps = fragment['UNIX_TIMESTAMP']
    fragment_acc_x = fragment['ACC_X']
    fragment_acc_y = fragment['ACC_Y']
    fragment_acc_z = fragment['ACC_Z']
    
    # Plotear el fragmento de ACC_Z
    plt.figure()
    plt.plot(fragment_acc_z)
    plt.title(f"Fragmento {i+1}")
    plt.xlabel("Índice")
    plt.ylabel("ACC_Z")
    plt.grid(True)
    plt.show()
    
    fragments.append(fragment)
    
# Directorio donde se guardarán los archivos CSV
directory = "C:/Users/Holacons/OneDrive - Vueling Airlines, S.A/Escritorio/TFM/fragmentos_tiempo"


if not os.path.exists(directory):
    os.makedirs(directory)

# Itera sobre los fragmentos y guárdalos como archivos CSV
for i, fragment in enumerate(fragments):
    # Nombre del archivo CSV
    filename = os.path.join(directory, f"reves_J1_{i+1}.csv")
    
    # Guardar el fragmento como archivo CSV
    df_fragment = pd.DataFrame(fragment, columns=['UNIX_TIMESTAMP', 'ACC_X', 'ACC_Y', 'ACC_Z'])
    df_fragment.to_csv(filename, index=False)

# %%
# Directorio donde se guardarán los archivos CSV
directory = "C:/Users/Holacons/OneDrive - Vueling Airlines, S.A/Escritorio/TFM/fragmentos_tiempo"

# Si el directorio no existe, créalo
if not os.path.exists(directory):
    os.makedirs(directory)

# Itera sobre los fragmentos y guárdalos como archivos CSV
for i, fragment in enumerate(fragments):
    # Nombre del archivo CSV
    filename = os.path.join(directory, f"serve_J1_{i+1}.csv")
    
    # Guardar el fragmento como archivo CSV
    df_fragment = pd.DataFrame(fragment, columns=['UNIX_TIMESTAMP', 'ACC_X', 'ACC_Y', 'ACC_Z'])
    df_fragment.to_csv(filename, index=False)

# %%
# Suponiendo que 'array_dreta' es un ndarray que contiene las columnas 'UNIX_TIMESTAMP', 'ACC_X', 'ACC_Y' y 'ACC_Z'
timestamps = array_smash['UNIX_TIMESTAMP']
acc_x_values = array_smash['ACC_X']
acc_y_values = array_smash['ACC_Y']
acc_z_values = array_smash['ACC_Z']

def find_closest_index(arr, target):
    return np.abs(arr - target).argmin()

fragments = []

# Fragmentar la señal alrededor de cada pico y plotear cada fragmento
for i, peak_index in enumerate(peaks):
    peak_time = timestamps[peak_index]
    start_time = peak_time - 1900
    end_time = peak_time + 1900

    start_index = find_closest_index(timestamps, start_time)
    end_index = find_closest_index(timestamps, end_time)
    
    fragment = array_smash[start_index:end_index + 1]
    
    # Obtener las columnas de cada fragmento
    fragment_timestamps = fragment['UNIX_TIMESTAMP']
    fragment_acc_x = fragment['ACC_X']
    fragment_acc_y = fragment['ACC_Y']
    fragment_acc_z = fragment['ACC_Z']
    
    # Plotear el fragmento de ACC_Z
    plt.figure()
    plt.plot(fragment_acc_z)
    plt.title(f"Fragmento {i+1}")
    plt.xlabel("Índice")
    plt.ylabel("ACC_Z")
    plt.grid(True)
    plt.show()
    
    fragments.append(fragment)
    
# Directorio donde se guardarán los archivos CSV
directory = "C:/Users/Holacons/OneDrive - Vueling Airlines, S.A/Escritorio/TFM/fragmentos_tiempo"

# Si el directorio no existe, créalo
if not os.path.exists(directory):
    os.makedirs(directory)

# Itera sobre los fragmentos y guárdalos como archivos CSV
for i, fragment in enumerate(fragments):
    # Nombre del archivo CSV
    filename = os.path.join(directory, f"smash_J1_{i+1}.csv")
    
    # Guardar el fragmento como archivo CSV
    df_fragment = pd.DataFrame(fragment, columns=['UNIX_TIMESTAMP', 'ACC_X', 'ACC_Y', 'ACC_Z'])
    df_fragment.to_csv(filename, index=False)

# %%
# Suponiendo que 'array_dreta' es un ndarray que contiene las columnas 'UNIX_TIMESTAMP', 'ACC_X', 'ACC_Y' y 'ACC_Z'
timestamps = array_vd['UNIX_TIMESTAMP']
acc_x_values = array_vd['ACC_X']
acc_y_values = array_vd['ACC_Y']
acc_z_values = array_vd['ACC_Z']

def find_closest_index(arr, target):
    return np.abs(arr - target).argmin()

fragments = []

# Fragmentar la señal alrededor de cada pico y plotear cada fragmento
for i, peak_index in enumerate(peaks):
    peak_time = timestamps[peak_index]
    start_time = peak_time - 1900
    end_time = peak_time + 1900

    start_index = find_closest_index(timestamps, start_time)
    end_index = find_closest_index(timestamps, end_time)
    
    fragment = array_vd[start_index:end_index + 1]
    
    # Obtener las columnas de cada fragmento
    fragment_timestamps = fragment['UNIX_TIMESTAMP']
    fragment_acc_x = fragment['ACC_X']
    fragment_acc_y = fragment['ACC_Y']
    fragment_acc_z = fragment['ACC_Z']
    
    # Plotear el fragmento de ACC_Z
    plt.figure()
    plt.plot(fragment_acc_z)
    plt.title(f"Fragmento {i+1}")
    plt.xlabel("Índice")
    plt.ylabel("ACC_Z")
    plt.grid(True)
    plt.show()
    
    fragments.append(fragment)
    
# Directorio donde se guardarán los archivos CSV
directory = "C:/Users/Holacons/OneDrive - Vueling Airlines, S.A/Escritorio/TFM/fragmentos_tiempo"

# Si el directorio no existe, créalo
if not os.path.exists(directory):
    os.makedirs(directory)

# Itera sobre los fragmentos y guárdalos como archivos CSV
for i, fragment in enumerate(fragments):
    # Nombre del archivo CSV
    filename = os.path.join(directory, f"vd_J1_{i+1}.csv")
    
    # Guardar el fragmento como archivo CSV
    df_fragment = pd.DataFrame(fragment, columns=['UNIX_TIMESTAMP', 'ACC_X', 'ACC_Y', 'ACC_Z'])
    df_fragment.to_csv(filename, index=False)

# %%
# Suponiendo que 'array_dreta' es un ndarray que contiene las columnas 'UNIX_TIMESTAMP', 'ACC_X', 'ACC_Y' y 'ACC_Z'
timestamps = array_vr['UNIX_TIMESTAMP']
acc_x_values = array_vr['ACC_X']
acc_y_values = array_vr['ACC_Y']
acc_z_values = array_vr['ACC_Z']

def find_closest_index(arr, target):
    return np.abs(arr - target).argmin()

fragments = []

# Fragmentar la señal alrededor de cada pico y plotear cada fragmento
for i, peak_index in enumerate(peaks):
    peak_time = timestamps[peak_index]
    start_time = peak_time - 1900
    end_time = peak_time + 1900

    start_index = find_closest_index(timestamps, start_time)
    end_index = find_closest_index(timestamps, end_time)
    
    fragment = array_vr[start_index:end_index + 1]
    
    # Obtener las columnas de cada fragmento
    fragment_timestamps = fragment['UNIX_TIMESTAMP']
    fragment_acc_x = fragment['ACC_X']
    fragment_acc_y = fragment['ACC_Y']
    fragment_acc_z = fragment['ACC_Z']
    
    # Plotear el fragmento de ACC_Z
    plt.figure()
    plt.plot(fragment_acc_z)
    plt.title(f"Fragmento {i+1}")
    plt.xlabel("Índice")
    plt.ylabel("ACC_Z")
    plt.grid(True)
    plt.show()
    
    fragments.append(fragment)
    
# Directorio donde se guardarán los archivos CSV
directory = "C:/Users/Holacons/OneDrive - Vueling Airlines, S.A/Escritorio/TFM/fragmentos_tiempo"

# Si el directorio no existe, créalo
if not os.path.exists(directory):
    os.makedirs(directory)

# Itera sobre los fragmentos y guárdalos como archivos CSV
for i, fragment in enumerate(fragments):
    # Nombre del archivo CSV
    filename = os.path.join(directory, f"vr_J1_{i+1}.csv")
    
    # Guardar el fragmento como archivo CSV
    df_fragment = pd.DataFrame(fragment, columns=['UNIX_TIMESTAMP', 'ACC_X', 'ACC_Y', 'ACC_Z'])
    df_fragment.to_csv(filename, index=False)
