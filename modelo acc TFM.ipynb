# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.utils import to_categorical
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score

from sklearn.model_selection import GroupKFold, cross_val_score
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.neural_network import MLPClassifier
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, SimpleRNN
from sklearn.preprocessing import LabelEncoder
from sklearn.pipeline import Pipeline
from sklearn.base import clone
# Out:
# WARNING:tensorflow:From C:\Users\Holacons\anaconda3\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
def leer_csvs_carpeta_en_dataframe(input_folder):
    # Lista para almacenar los DataFrames individuales
    dataframes = []
    
    # Iterar sobre cada archivo en la carpeta
    for file_name in os.listdir(input_folder):
        if file_name.endswith('.csv'):
            file_path = os.path.join(input_folder, file_name)
            # Leer el archivo CSV y añadirlo a la lista de DataFrames
            df = pd.read_csv(file_path)
            dataframes.append(df)
    
    # Concatenar todos los DataFrames en uno solo
    df_combinado = pd.concat(dataframes, ignore_index=True)
    
    return df_combinado

# Uso de la función
ruta_carpeta = "C:/Users/Holacons/OneDrive - Vueling Airlines, S.A/Escritorio/TFM/para_modelo"
df_combinado = leer_csvs_carpeta_en_dataframe(ruta_carpeta)

# Mostrar el DataFrame resultante
df_combinado.head()
# Out:
#     ACC_X_1   ACC_Y_1   ACC_Z_1   ACC_X_2   ACC_Y_2   ACC_Z_2   ACC_X_3  \
# 0  0.190296  0.076082  0.920818  0.189784  0.075668  0.920838  0.189273
# 1  0.271055  0.125510  0.901010  0.270647  0.125342  0.901675  0.270239
# 2  0.183005  0.072047  0.906640  0.182438  0.071752  0.906833  0.181871
# 3  0.209824  0.091860  0.918668  0.210336  0.092459  0.919214  0.210847
# 4  0.197163  0.084217  0.922922  0.198047  0.084980  0.923411  0.198930
#
#     ACC_Y_3   ACC_Z_3   ACC_X_4  ...  ACC_Z_630  ACC_X_631  ACC_Y_631  \
# 0  0.075254  0.920857  0.188761  ...   0.918540   0.170024   0.060955
# 1  0.125173  0.902341  0.269831  ...   0.905127   0.188410   0.074876
# 2  0.071457  0.907026  0.181304  ...   0.913423   0.204554   0.085829
# 3  0.093058  0.919760  0.211359  ...   0.918754   0.190265   0.078249
# 4  0.085743  0.923901  0.199814  ...   0.909193   0.169465   0.069462
#
#    ACC_Z_631  ACC_X_632  ACC_Y_632  ACC_Z_632  TIPO_GOLPE  JUGADOR  N_MUESTRA
# 0   0.919014   0.170943   0.061517   0.919488     derecha       J2          1
# 1   0.905242   0.187863   0.074590   0.905358     derecha       J2         10
# 2   0.913899   0.205163   0.086504   0.914375     derecha       J2         11
# 3   0.919136   0.190932   0.078838   0.919519     derecha       J2         12
# 4   0.909143   0.169215   0.069274   0.909093     derecha       J2         13
#
# [5 rows x 1899 columns]

# %%
# Reemplazar 'J' por una cadena vacía para dejar solo los números
df_combinado['JUGADOR'] = df_combinado['JUGADOR'].str.replace('J', '')

# %%
df_final = df_combinado

# %%
for col in df_final.columns:
    try:
        df_final[col] = df_final[col].astype(float)
    except ValueError:
        print(f"No se pudo convertir la columna {col} a float")

# Verificar que la conversión se realizó correctamente
print(df_final.dtypes)
# Out:
# No se pudo convertir la columna TIPO_GOLPE a float
# ACC_X_1       float64
# ACC_Y_1       float64
# ACC_Z_1       float64
# ACC_X_2       float64
# ACC_Y_2       float64
#                ...
# ACC_Y_632     float64
# ACC_Z_632     float64
# TIPO_GOLPE     object
# JUGADOR       float64
# N_MUESTRA     float64
# Length: 1899, dtype: object

# %%
train_df_6 = df_final[df_final['JUGADOR']!= 6]
test_df_6 = df_final[df_final['JUGADOR']== 6]

# %%
train_df_5 = df_final[df_final['JUGADOR']!= 5]
test_df_5 = df_final[df_final['JUGADOR']== 5]

train_df_4 = df_final[df_final['JUGADOR']!= 4]
test_df_4 = df_final[df_final['JUGADOR']== 4]

train_df_3 = df_final[df_final['JUGADOR']!= 3]
test_df_3 = df_final[df_final['JUGADOR']== 3]

train_df_2 = df_final[df_final['JUGADOR']!= 2]
test_df_2 = df_final[df_final['JUGADOR']== 2]

train_df_1 = df_final[df_final['JUGADOR']!= 1]
test_df_1 = df_final[df_final['JUGADOR']== 1]

# %%
X_train_6 = train_df_6.drop(columns=['TIPO_GOLPE'])  # Características
y_train_6 = train_df_6['TIPO_GOLPE']  # Etiquetas

X_train_5 = train_df_5.drop(columns=['TIPO_GOLPE'])  # Características
y_train_5 = train_df_5['TIPO_GOLPE']  # Etiquetas

X_train_4 = train_df_4.drop(columns=['TIPO_GOLPE'])  # Características
y_train_4 = train_df_4['TIPO_GOLPE']  # Etiquetas

X_train_3 = train_df_3.drop(columns=['TIPO_GOLPE'])  # Características
y_train_3 = train_df_3['TIPO_GOLPE']  # Etiquetas

X_train_2 = train_df_2.drop(columns=['TIPO_GOLPE'])  # Características
y_train_2 = train_df_2['TIPO_GOLPE']  # Etiquetas

X_train_1 = train_df_1.drop(columns=['TIPO_GOLPE'])  # Características
y_train_1 = train_df_1['TIPO_GOLPE']  # Etiquetas

# %%
X_test_6 = test_df_6.drop(columns=['TIPO_GOLPE'])  # Características
y_test_6 = test_df_6['TIPO_GOLPE']  # Etiquetas

X_test_5 = test_df_5.drop(columns=['TIPO_GOLPE'])  # Características
y_test_5 = test_df_5['TIPO_GOLPE']  # Etiquetas

X_test_4 = test_df_4.drop(columns=['TIPO_GOLPE'])  # Características
y_test_4 = test_df_4['TIPO_GOLPE']  # Etiquetas

X_test_3 = test_df_3.drop(columns=['TIPO_GOLPE'])  # Características
y_test_3 = test_df_3['TIPO_GOLPE']  # Etiquetas

X_test_2 = test_df_2.drop(columns=['TIPO_GOLPE'])  # Características
y_test_2 = test_df_2['TIPO_GOLPE']  # Etiquetas

X_test_1 = test_df_1.drop(columns=['TIPO_GOLPE'])  # Características
y_test_1 = test_df_1['TIPO_GOLPE']  # Etiquetas

# %%
from pycaret.classification import *

# Preparar el entorno de PyCaret
clf = setup(data=df_final, 
            target='TIPO_GOLPE',  # Reemplaza 'tipo_golpe' con el nombre de tu columna objetivo
            train_size=0.8,
            session_id=123)  # session_id para reproducibilidad

# Comparar modelos y seleccionar el mejor
best_model = compare_models()

# Ver los mejores modelos
results = pull()
print(results)

# Entrenar el mejor modelo en todo el conjunto de entrenamiento
final_model = finalize_model(best_model)

# Evaluar el mejor modelo en el conjunto de prueba
predictions = predict_model(final_model)
# Out:
# <style type="text/css">
# #T_2118d_row9_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_2118d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2118d_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_2118d_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2118d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_2118d_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_2118d_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_2118d_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_2118d_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_2118d_row1_col1" class="data row1 col1" >TIPO_GOLPE</td>
#     </tr>
#     <tr>
#       <th id="T_2118d_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_2118d_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_2118d_row2_col1" class="data row2 col1" >Multiclass</td>
#     </tr>
#     <tr>
#       <th id="T_2118d_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_2118d_row3_col0" class="data row3 col0" >Target mapping</td>
#       <td id="T_2118d_row3_col1" class="data row3 col1" >derecha: 0, reves: 1, serve: 2, smash: 3, vd: 4, vr: 5</td>
#     </tr>
#     <tr>
#       <th id="T_2118d_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_2118d_row4_col0" class="data row4 col0" >Original data shape</td>
#       <td id="T_2118d_row4_col1" class="data row4 col1" >(723, 7581)</td>
#     </tr>
#     <tr>
#       <th id="T_2118d_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_2118d_row5_col0" class="data row5 col0" >Transformed data shape</td>
#       <td id="T_2118d_row5_col1" class="data row5 col1" >(723, 7581)</td>
#     </tr>
#     <tr>
#       <th id="T_2118d_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_2118d_row6_col0" class="data row6 col0" >Transformed train set shape</td>
#       <td id="T_2118d_row6_col1" class="data row6 col1" >(578, 7581)</td>
#     </tr>
#     <tr>
#       <th id="T_2118d_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_2118d_row7_col0" class="data row7 col0" >Transformed test set shape</td>
#       <td id="T_2118d_row7_col1" class="data row7 col1" >(145, 7581)</td>
#     </tr>
#     <tr>
#       <th id="T_2118d_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_2118d_row8_col0" class="data row8 col0" >Numeric features</td>
#       <td id="T_2118d_row8_col1" class="data row8 col1" >7580</td>
#     </tr>
#     <tr>
#       <th id="T_2118d_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_2118d_row9_col0" class="data row9 col0" >Preprocess</td>
#       <td id="T_2118d_row9_col1" class="data row9 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_2118d_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_2118d_row10_col0" class="data row10 col0" >Imputation type</td>
#       <td id="T_2118d_row10_col1" class="data row10 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_2118d_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_2118d_row11_col0" class="data row11 col0" >Numeric imputation</td>
#       <td id="T_2118d_row11_col1" class="data row11 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_2118d_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_2118d_row12_col0" class="data row12 col0" >Categorical imputation</td>
#       <td id="T_2118d_row12_col1" class="data row12 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_2118d_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_2118d_row13_col0" class="data row13 col0" >Fold Generator</td>
#       <td id="T_2118d_row13_col1" class="data row13 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_2118d_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_2118d_row14_col0" class="data row14 col0" >Fold Number</td>
#       <td id="T_2118d_row14_col1" class="data row14 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_2118d_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_2118d_row15_col0" class="data row15 col0" >CPU Jobs</td>
#       <td id="T_2118d_row15_col1" class="data row15 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_2118d_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_2118d_row16_col0" class="data row16 col0" >Use GPU</td>
#       <td id="T_2118d_row16_col1" class="data row16 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_2118d_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_2118d_row17_col0" class="data row17 col0" >Log Experiment</td>
#       <td id="T_2118d_row17_col1" class="data row17 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_2118d_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_2118d_row18_col0" class="data row18 col0" >Experiment Name</td>
#       <td id="T_2118d_row18_col1" class="data row18 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_2118d_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_2118d_row19_col0" class="data row19 col0" >USI</td>
#       <td id="T_2118d_row19_col1" class="data row19 col1" >6320</td>
#     </tr>
#   </tbody>
# </table>
#
#
# Initiated  . . . . . . . . . . . . . . . . . .                      17:29:21
# Status     . . . . . . . . . . . . . . . . . .              Fitting 10 Folds
# Estimator  . . . . . . . . . . . . . . . . . .  Gradient Boosting Classifier
# <style type="text/css">
# #T_45aca th {
#   text-align: left;
# }
# #T_45aca_row0_col0, #T_45aca_row0_col1, #T_45aca_row0_col2, #T_45aca_row0_col3, #T_45aca_row0_col4, #T_45aca_row0_col5, #T_45aca_row0_col6, #T_45aca_row0_col7, #T_45aca_row0_col8, #T_45aca_row1_col0, #T_45aca_row1_col1, #T_45aca_row1_col2, #T_45aca_row1_col3, #T_45aca_row1_col4, #T_45aca_row1_col5, #T_45aca_row1_col6, #T_45aca_row1_col7, #T_45aca_row1_col8, #T_45aca_row2_col0, #T_45aca_row2_col1, #T_45aca_row2_col2, #T_45aca_row2_col3, #T_45aca_row2_col4, #T_45aca_row2_col5, #T_45aca_row2_col6, #T_45aca_row2_col7, #T_45aca_row2_col8, #T_45aca_row3_col0, #T_45aca_row3_col1, #T_45aca_row3_col2, #T_45aca_row3_col3, #T_45aca_row3_col4, #T_45aca_row3_col5, #T_45aca_row3_col6, #T_45aca_row3_col7, #T_45aca_row3_col8, #T_45aca_row4_col0, #T_45aca_row4_col1, #T_45aca_row4_col2, #T_45aca_row4_col3, #T_45aca_row4_col4, #T_45aca_row4_col5, #T_45aca_row4_col6, #T_45aca_row4_col7, #T_45aca_row4_col8, #T_45aca_row5_col0, #T_45aca_row5_col1, #T_45aca_row5_col2, #T_45aca_row5_col3, #T_45aca_row5_col4, #T_45aca_row5_col5, #T_45aca_row5_col6, #T_45aca_row5_col7, #T_45aca_row5_col8, #T_45aca_row6_col0, #T_45aca_row6_col1, #T_45aca_row6_col2, #T_45aca_row6_col3, #T_45aca_row6_col4, #T_45aca_row6_col5, #T_45aca_row6_col6, #T_45aca_row6_col7, #T_45aca_row6_col8, #T_45aca_row7_col0, #T_45aca_row7_col1, #T_45aca_row7_col2, #T_45aca_row7_col3, #T_45aca_row7_col4, #T_45aca_row7_col5, #T_45aca_row7_col6, #T_45aca_row7_col7, #T_45aca_row7_col8, #T_45aca_row8_col0, #T_45aca_row8_col1, #T_45aca_row8_col2, #T_45aca_row8_col3, #T_45aca_row8_col4, #T_45aca_row8_col5, #T_45aca_row8_col6, #T_45aca_row8_col7, #T_45aca_row8_col8 {
#   text-align: left;
# }
# </style>
# <table id="T_45aca">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_45aca_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_45aca_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_45aca_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_45aca_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_45aca_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_45aca_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_45aca_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_45aca_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_45aca_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_45aca_level0_row0" class="row_heading level0 row0" >rf</th>
#       <td id="T_45aca_row0_col0" class="data row0 col0" >Random Forest Classifier</td>
#       <td id="T_45aca_row0_col1" class="data row0 col1" >0.9273</td>
#       <td id="T_45aca_row0_col2" class="data row0 col2" >0.9966</td>
#       <td id="T_45aca_row0_col3" class="data row0 col3" >0.9273</td>
#       <td id="T_45aca_row0_col4" class="data row0 col4" >0.9343</td>
#       <td id="T_45aca_row0_col5" class="data row0 col5" >0.9234</td>
#       <td id="T_45aca_row0_col6" class="data row0 col6" >0.9104</td>
#       <td id="T_45aca_row0_col7" class="data row0 col7" >0.9127</td>
#       <td id="T_45aca_row0_col8" class="data row0 col8" >0.9300</td>
#     </tr>
#     <tr>
#       <th id="T_45aca_level0_row1" class="row_heading level0 row1" >nb</th>
#       <td id="T_45aca_row1_col0" class="data row1 col0" >Naive Bayes</td>
#       <td id="T_45aca_row1_col1" class="data row1 col1" >0.8095</td>
#       <td id="T_45aca_row1_col2" class="data row1 col2" >0.9156</td>
#       <td id="T_45aca_row1_col3" class="data row1 col3" >0.8095</td>
#       <td id="T_45aca_row1_col4" class="data row1 col4" >0.8227</td>
#       <td id="T_45aca_row1_col5" class="data row1 col5" >0.8064</td>
#       <td id="T_45aca_row1_col6" class="data row1 col6" >0.7655</td>
#       <td id="T_45aca_row1_col7" class="data row1 col7" >0.7690</td>
#       <td id="T_45aca_row1_col8" class="data row1 col8" >0.2050</td>
#     </tr>
#     <tr>
#       <th id="T_45aca_level0_row2" class="row_heading level0 row2" >lr</th>
#       <td id="T_45aca_row2_col0" class="data row2 col0" >Logistic Regression</td>
#       <td id="T_45aca_row2_col1" class="data row2 col1" >0.7766</td>
#       <td id="T_45aca_row2_col2" class="data row2 col2" >0.9451</td>
#       <td id="T_45aca_row2_col3" class="data row2 col3" >0.7766</td>
#       <td id="T_45aca_row2_col4" class="data row2 col4" >0.7872</td>
#       <td id="T_45aca_row2_col5" class="data row2 col5" >0.7681</td>
#       <td id="T_45aca_row2_col6" class="data row2 col6" >0.7253</td>
#       <td id="T_45aca_row2_col7" class="data row2 col7" >0.7300</td>
#       <td id="T_45aca_row2_col8" class="data row2 col8" >6.7140</td>
#     </tr>
#     <tr>
#       <th id="T_45aca_level0_row3" class="row_heading level0 row3" >dt</th>
#       <td id="T_45aca_row3_col0" class="data row3 col0" >Decision Tree Classifier</td>
#       <td id="T_45aca_row3_col1" class="data row3 col1" >0.7665</td>
#       <td id="T_45aca_row3_col2" class="data row3 col2" >0.8567</td>
#       <td id="T_45aca_row3_col3" class="data row3 col3" >0.7665</td>
#       <td id="T_45aca_row3_col4" class="data row3 col4" >0.7875</td>
#       <td id="T_45aca_row3_col5" class="data row3 col5" >0.7643</td>
#       <td id="T_45aca_row3_col6" class="data row3 col6" >0.7131</td>
#       <td id="T_45aca_row3_col7" class="data row3 col7" >0.7167</td>
#       <td id="T_45aca_row3_col8" class="data row3 col8" >0.7660</td>
#     </tr>
#     <tr>
#       <th id="T_45aca_level0_row4" class="row_heading level0 row4" >svm</th>
#       <td id="T_45aca_row4_col0" class="data row4 col0" >SVM - Linear Kernel</td>
#       <td id="T_45aca_row4_col1" class="data row4 col1" >0.7629</td>
#       <td id="T_45aca_row4_col2" class="data row4 col2" >0.0000</td>
#       <td id="T_45aca_row4_col3" class="data row4 col3" >0.7629</td>
#       <td id="T_45aca_row4_col4" class="data row4 col4" >0.7820</td>
#       <td id="T_45aca_row4_col5" class="data row4 col5" >0.7607</td>
#       <td id="T_45aca_row4_col6" class="data row4 col6" >0.7097</td>
#       <td id="T_45aca_row4_col7" class="data row4 col7" >0.7140</td>
#       <td id="T_45aca_row4_col8" class="data row4 col8" >0.4390</td>
#     </tr>
#     <tr>
#       <th id="T_45aca_level0_row5" class="row_heading level0 row5" >knn</th>
#       <td id="T_45aca_row5_col0" class="data row5 col0" >K Neighbors Classifier</td>
#       <td id="T_45aca_row5_col1" class="data row5 col1" >0.6989</td>
#       <td id="T_45aca_row5_col2" class="data row5 col2" >0.9130</td>
#       <td id="T_45aca_row5_col3" class="data row5 col3" >0.6989</td>
#       <td id="T_45aca_row5_col4" class="data row5 col4" >0.7814</td>
#       <td id="T_45aca_row5_col5" class="data row5 col5" >0.6918</td>
#       <td id="T_45aca_row5_col6" class="data row5 col6" >0.6315</td>
#       <td id="T_45aca_row5_col7" class="data row5 col7" >0.6470</td>
#       <td id="T_45aca_row5_col8" class="data row5 col8" >0.9240</td>
#     </tr>
#     <tr>
#       <th id="T_45aca_level0_row6" class="row_heading level0 row6" >ridge</th>
#       <td id="T_45aca_row6_col0" class="data row6 col0" >Ridge Classifier</td>
#       <td id="T_45aca_row6_col1" class="data row6 col1" >0.5792</td>
#       <td id="T_45aca_row6_col2" class="data row6 col2" >0.0000</td>
#       <td id="T_45aca_row6_col3" class="data row6 col3" >0.5792</td>
#       <td id="T_45aca_row6_col4" class="data row6 col4" >0.5687</td>
#       <td id="T_45aca_row6_col5" class="data row6 col5" >0.5533</td>
#       <td id="T_45aca_row6_col6" class="data row6 col6" >0.4827</td>
#       <td id="T_45aca_row6_col7" class="data row6 col7" >0.4905</td>
#       <td id="T_45aca_row6_col8" class="data row6 col8" >0.2000</td>
#     </tr>
#     <tr>
#       <th id="T_45aca_level0_row7" class="row_heading level0 row7" >ada</th>
#       <td id="T_45aca_row7_col0" class="data row7 col0" >Ada Boost Classifier</td>
#       <td id="T_45aca_row7_col1" class="data row7 col1" >0.4670</td>
#       <td id="T_45aca_row7_col2" class="data row7 col2" >0.7623</td>
#       <td id="T_45aca_row7_col3" class="data
# Processing:   0%|          | 0/61 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[16], line 10
#       4 clf = setup(data=df_final,
#       5             target='TIPO_GOLPE',  # Reemplaza 'tipo_golpe' con el nombre de tu columna objetivo
#       6             train_size=0.8,
#       7             session_id=123)  # session_id para reproducibilidad
#       9 # Comparar modelos y seleccionar el mejor
# ---> 10 best_model = compare_models()
#      12 # Ver los mejores modelos
#      13 results = pull()
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pycaret\utils\generic.py:965, in check_if_global_is_not_none.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     963     if globals_d[name] is None:
#     964         raise ValueError(message)
# --> 965 return func(*args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pycaret\classification\functional.py:814, in compare_models(include, exclude, fold, round, cross_validation, sort, n_select, budget_time, turbo, errors, fit_kwargs, groups, experiment_custom_tags, probability_threshold, engine, verbose, parallel)
#     672 @check_if_global_is_not_none(globals(), _CURRENT_EXPERIMENT_DECORATOR_DICT)
#     673 def compare_models(
#     674     include: Optional[List[Union[str, Any]]] = None,
#    (...)
#     690     parallel: Optional[ParallelBackend] = None,
#     691 ) -> Union[Any, List[Any]]:
#     692     """
#     693     This function trains and evaluates performance of all estimators available in the
#     694     model library using cross validation. The output of this function is a score grid
#    (...)
#     811     - No models are logged in ``MLFlow`` when ``cross_validation`` parameter is False.
#     812     """
# --> 814     return _CURRENT_EXPERIMENT.compare_models(
#     815         include=include,
#     816         exclude=exclude,
#     817         fold=fold,
#     818         round=round,
#     819         cross_validation=cross_validation,
#     820         sort=sort,
#     821         n_select=n_select,
#     822         budget_time=budget_time,
#     823         turbo=turbo,
#     824         errors=errors,
#     825         fit_kwargs=fit_kwargs,
#     826         groups=groups,
#     827         experiment_custom_tags=experiment_custom_tags,
#     828         probability_threshold=probability_threshold,
#     829         engine=engine,
#     830         verbose=verbose,
#     831         parallel=parallel,
#     832     )
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pycaret\classification\oop.py:1180, in ClassificationExperiment.compare_models(self, include, exclude, fold, round, cross_validation, sort, n_select, budget_time, turbo, errors, fit_kwargs, groups, experiment_custom_tags, probability_threshold, engine, verbose, parallel)
#    1177         self._set_engine(estimator=estimator, engine=eng, severity="error")
#    1179 try:
# -> 1180     return_values = super().compare_models(
#    1181         include=include,
#    1182         exclude=exclude,
#    1183         fold=fold,
#    1184         round=round,
#    1185         cross_validation=cross_validation,
#    1186         sort=sort,
#    1187         n_select=n_select,
#    1188         budget_time=budget_time,
#    1189         turbo=turbo,
#    1190         errors=errors,
#    1191         fit_kwargs=fit_kwargs,
#    1192         groups=groups,
#    1193         experiment_custom_tags=experiment_custom_tags,
#    1194         verbose=verbose,
#    1195         probability_threshold=probability_threshold,
#    1196         parallel=parallel,
#    1197         caller_params=caller_params,
#    1198     )
#    1199 finally:
#    1200     if engine is not None:
#    1201         # Reset the models back to the default engines
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pycaret\internal\pycaret_experiment\supervised_experiment.py:794, in _SupervisedExperiment.compare_models(self, include, exclude, fold, round, cross_validation, sort, n_select, budget_time, turbo, errors, fit_kwargs, groups, experiment_custom_tags, probability_threshold, verbose, parallel, caller_params)
#     791 results_columns_to_ignore = ["Object", "runtime", "cutoff"]
#     793 try:
# --> 794     model, model_fit_time = self._create_model(**create_model_args)
#     795     model_results = self.pull(pop=True)
#     796     assert (
#     797         np.sum(
#     798             model_results.drop(
#    (...)
#     802         != 0.0
#     803     )
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pycaret\internal\pycaret_experiment\supervised_experiment.py:1533, in _SupervisedExperiment._create_model(self, estimator, fold, round, cross_validation, predict, fit_kwargs, groups, refit, probability_threshold, experiment_custom_tags, verbose, system, add_to_model_list, X_train_data, y_train_data, metrics, display, model_only, return_train_score, error_score, **kwargs)
#    1530         return model, model_fit_time
#    1531     return model
# -> 1533 model, model_fit_time, model_results, _ = self._create_model_with_cv(
#    1534     model=model,
#    1535     data_X=data_X,
#    1536     data_y=data_y,
#    1537     fit_kwargs=fit_kwargs,
#    1538     round=round,
#    1539     cv=cv,
#    1540     groups=groups,
#    1541     metrics=metrics,
#    1542     refit=refit,
#    1543     system=system,
#    1544     display=display,
#    1545     error_score=error_score,
#    1546     return_train_score=return_train_score,
#    1547 )
#    1549 # end runtime
#    1550 runtime_end = time.time()
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pycaret\internal\pycaret_experiment\supervised_experiment.py:1126, in _SupervisedExperiment._create_model_with_cv(self, model, data_X, data_y, fit_kwargs, round, cv, groups, metrics, refit, system, display, error_score, return_train_score)
#    1124     model_fit_start = time.time()
#    1125     with redirect_output(self.logger):
# -> 1126         scores = cross_validate(
#    1127             pipeline_with_model,
#    1128             data_X,
#    1129             data_y,
#    1130             cv=cv,
#    1131             groups=groups,
#    1132             scoring=metrics_dict,
#    1133             fit_params=fit_kwargs,
#    1134             n_jobs=n_jobs,
#    1135             return_train_score=return_train_score,
#    1136             error_score=error_score,
#    1137         )
#    1139 model_fit_end = time.time()
#    1140 model_fit_time = np.array(model_fit_end - model_fit_start).round(2)
#
# File ~\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:266, in cross_validate(estimator, X, y, groups, scoring, cv, n_jobs, verbose, fit_params, pre_dispatch, return_train_score, return_estimator, error_score)
#     263 # We clone the estimator to make sure that all the folds are
#     264 # independent, and that it is pickle-able.
#     265 parallel = Parallel(n_jobs=n_jobs, verbose=verbose, pre_dispatch=pre_dispatch)
# --> 266 results = parallel(
#     267     delayed(_fit_and_score)(
#     268         clone(estimator),
#     269         X,
#     270         y,
#     271         scorers,
#     272         train,
#     273         test,
#     274         verbose,
#     275         None,
#     276         fit_params,
#     277         return_train_score=return_train_score,
#     278         return_times=True,
#     279         return_estimator=return_estimator,
#     280         error_score=error_score,
#     281     )
#     282     for train, test in cv.split(X, y, groups)
#     283 )
#     285 _warn_or_raise_about_fit_failures(results, error_score)
#     287 # For callabe scoring, the return type is only know after calling. If the
#     288 # return type is a dictionary, the error scores can now be inserted with
#     289 # the correct key.
#
# File ~\anaconda3\lib\site-packages\sklearn\utils\parallel.py:63, in Parallel.__call__(self, iterable)
#      58 config = get_config()
#      59 iterable_with_config = (
#      60     (_with_config(delayed_func, config), args, kwargs)
#      61     for delayed_func, args, kwargs in iterable
#      62 )
# ---> 63 return super().__call__(iterable_with_config)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\joblib\parallel.py:1952, in Parallel.__call__(self, iterable)
#    1946 # The first item from the output is blank, but it makes the interpreter
#    1947 # progress until it enters the Try/Except block of the generator and
#    1948 # reach the first `yield` statement. This starts the aynchronous
#    1949 # dispatch of the tasks to the workers.
#    1950 next(output)
# -> 1952 return output if self.return_generator else list(output)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\joblib\parallel.py:1595, in Parallel._get_outputs(self, iterator, pre_dispatch)
#    1592     yield
#    1594     with self._backend.retrieval_context():
# -> 1595         yield from self._retrieve()
#    1597 except GeneratorExit:
#    1598     # The generator has been garbage collected before being fully
#    1599     # consumed. This aborts the remaining tasks if possible and warn
#    1600     # the user if necessary.
#    1601     self._exception = True
#
# File ~\AppData\Roaming\Python\Python310\site-packages\joblib\parallel.py:1707, in Parallel._retrieve(self)
#    1702 # If the next job is not ready for retrieval yet, we just wait for
#    1703 # async callbacks to progress.
#    1704 if ((len(self._jobs) == 0) or
#    1705     (self._jobs[0].get_status(
#    1706         timeout=self.timeout) == TASK_PENDING)):
# -> 1707     time.sleep(0.01)
#    1708     continue
#    1710 # We need to be careful: the job list can be filling up as
#    1711 # we empty it and Python list are not thread-safe by
#    1712 # default hence the use of the lock
#
# KeyboardInterrupt:

# %%
# Comparar todos los modelos
best_model = compare_models()

# Ajustar los hiperparámetros del mejor modelo
tuned_best_model = tune_model(best_model)

# Mostrar los hiperparámetros ajustados
print(tuned_best_model)
# Out:
#
#
# Initiated  . . . . . . . . . . . . . . . . . .             17:52:23
# Status     . . . . . . . . . . . . . . . . . .     Fitting 10 Folds
# Estimator  . . . . . . . . . . . . . . . . . .  Logistic Regression
# Empty DataFrame
# Columns: [Model, Accuracy, AUC, Recall, Prec., F1, Kappa, MCC, TT (Sec)]
# Index: []
# Processing:   0%|          | 0/61 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[17], line 2
#       1 # Comparar todos los modelos
# ----> 2 best_model = compare_models()
#       4 # Ajustar los hiperparámetros del mejor modelo
#       5 tuned_best_model = tune_model(best_model)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pycaret\utils\generic.py:965, in check_if_global_is_not_none.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     963     if globals_d[name] is None:
#     964         raise ValueError(message)
# --> 965 return func(*args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pycaret\classification\functional.py:814, in compare_models(include, exclude, fold, round, cross_validation, sort, n_select, budget_time, turbo, errors, fit_kwargs, groups, experiment_custom_tags, probability_threshold, engine, verbose, parallel)
#     672 @check_if_global_is_not_none(globals(), _CURRENT_EXPERIMENT_DECORATOR_DICT)
#     673 def compare_models(
#     674     include: Optional[List[Union[str, Any]]] = None,
#    (...)
#     690     parallel: Optional[ParallelBackend] = None,
#     691 ) -> Union[Any, List[Any]]:
#     692     """
#     693     This function trains and evaluates performance of all estimators available in the
#     694     model library using cross validation. The output of this function is a score grid
#    (...)
#     811     - No models are logged in ``MLFlow`` when ``cross_validation`` parameter is False.
#     812     """
# --> 814     return _CURRENT_EXPERIMENT.compare_models(
#     815         include=include,
#     816         exclude=exclude,
#     817         fold=fold,
#     818         round=round,
#     819         cross_validation=cross_validation,
#     820         sort=sort,
#     821         n_select=n_select,
#     822         budget_time=budget_time,
#     823         turbo=turbo,
#     824         errors=errors,
#     825         fit_kwargs=fit_kwargs,
#     826         groups=groups,
#     827         experiment_custom_tags=experiment_custom_tags,
#     828         probability_threshold=probability_threshold,
#     829         engine=engine,
#     830         verbose=verbose,
#     831         parallel=parallel,
#     832     )
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pycaret\classification\oop.py:1180, in ClassificationExperiment.compare_models(self, include, exclude, fold, round, cross_validation, sort, n_select, budget_time, turbo, errors, fit_kwargs, groups, experiment_custom_tags, probability_threshold, engine, verbose, parallel)
#    1177         self._set_engine(estimator=estimator, engine=eng, severity="error")
#    1179 try:
# -> 1180     return_values = super().compare_models(
#    1181         include=include,
#    1182         exclude=exclude,
#    1183         fold=fold,
#    1184         round=round,
#    1185         cross_validation=cross_validation,
#    1186         sort=sort,
#    1187         n_select=n_select,
#    1188         budget_time=budget_time,
#    1189         turbo=turbo,
#    1190         errors=errors,
#    1191         fit_kwargs=fit_kwargs,
#    1192         groups=groups,
#    1193         experiment_custom_tags=experiment_custom_tags,
#    1194         verbose=verbose,
#    1195         probability_threshold=probability_threshold,
#    1196         parallel=parallel,
#    1197         caller_params=caller_params,
#    1198     )
#    1199 finally:
#    1200     if engine is not None:
#    1201         # Reset the models back to the default engines
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pycaret\internal\pycaret_experiment\supervised_experiment.py:794, in _SupervisedExperiment.compare_models(self, include, exclude, fold, round, cross_validation, sort, n_select, budget_time, turbo, errors, fit_kwargs, groups, experiment_custom_tags, probability_threshold, verbose, parallel, caller_params)
#     791 results_columns_to_ignore = ["Object", "runtime", "cutoff"]
#     793 try:
# --> 794     model, model_fit_time = self._create_model(**create_model_args)
#     795     model_results = self.pull(pop=True)
#     796     assert (
#     797         np.sum(
#     798             model_results.drop(
#    (...)
#     802         != 0.0
#     803     )
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pycaret\internal\pycaret_experiment\supervised_experiment.py:1533, in _SupervisedExperiment._create_model(self, estimator, fold, round, cross_validation, predict, fit_kwargs, groups, refit, probability_threshold, experiment_custom_tags, verbose, system, add_to_model_list, X_train_data, y_train_data, metrics, display, model_only, return_train_score, error_score, **kwargs)
#    1530         return model, model_fit_time
#    1531     return model
# -> 1533 model, model_fit_time, model_results, _ = self._create_model_with_cv(
#    1534     model=model,
#    1535     data_X=data_X,
#    1536     data_y=data_y,
#    1537     fit_kwargs=fit_kwargs,
#    1538     round=round,
#    1539     cv=cv,
#    1540     groups=groups,
#    1541     metrics=metrics,
#    1542     refit=refit,
#    1543     system=system,
#    1544     display=display,
#    1545     error_score=error_score,
#    1546     return_train_score=return_train_score,
#    1547 )
#    1549 # end runtime
#    1550 runtime_end = time.time()
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pycaret\internal\pycaret_experiment\supervised_experiment.py:1126, in _SupervisedExperiment._create_model_with_cv(self, model, data_X, data_y, fit_kwargs, round, cv, groups, metrics, refit, system, display, error_score, return_train_score)
#    1124     model_fit_start = time.time()
#    1125     with redirect_output(self.logger):
# -> 1126         scores = cross_validate(
#    1127             pipeline_with_model,
#    1128             data_X,
#    1129             data_y,
#    1130             cv=cv,
#    1131             groups=groups,
#    1132             scoring=metrics_dict,
#    1133             fit_params=fit_kwargs,
#    1134             n_jobs=n_jobs,
#    1135             return_train_score=return_train_score,
#    1136             error_score=error_score,
#    1137         )
#    1139 model_fit_end = time.time()
#    1140 model_fit_time = np.array(model_fit_end - model_fit_start).round(2)
#
# File ~\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:266, in cross_validate(estimator, X, y, groups, scoring, cv, n_jobs, verbose, fit_params, pre_dispatch, return_train_score, return_estimator, error_score)
#     263 # We clone the estimator to make sure that all the folds are
#     264 # independent, and that it is pickle-able.
#     265 parallel = Parallel(n_jobs=n_jobs, verbose=verbose, pre_dispatch=pre_dispatch)
# --> 266 results = parallel(
#     267     delayed(_fit_and_score)(
#     268         clone(estimator),
#     269         X,
#     270         y,
#     271         scorers,
#     272         train,
#     273         test,
#     274         verbose,
#     275         None,
#     276         fit_params,
#     277         return_train_score=return_train_score,
#     278         return_times=True,
#     279         return_estimator=return_estimator,
#     280         error_score=error_score,
#     281     )
#     282     for train, test in cv.split(X, y, groups)
#     283 )
#     285 _warn_or_raise_about_fit_failures(results, error_score)
#     287 # For callabe scoring, the return type is only know after calling. If the
#     288 # return type is a dictionary, the error scores can now be inserted with
#     289 # the correct key.
#
# File ~\anaconda3\lib\site-packages\sklearn\utils\parallel.py:63, in Parallel.__call__(self, iterable)
#      58 config = get_config()
#      59 iterable_with_config = (
#      60     (_with_config(delayed_func, config), args, kwargs)
#      61     for delayed_func, args, kwargs in iterable
#      62 )
# ---> 63 return super().__call__(iterable_with_config)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\joblib\parallel.py:1952, in Parallel.__call__(self, iterable)
#    1946 # The first item from the output is blank, but it makes the interpreter
#    1947 # progress until it enters the Try/Except block of the generator and
#    1948 # reach the first `yield` statement. This starts the aynchronous
#    1949 # dispatch of the tasks to the workers.
#    1950 next(output)
# -> 1952 return output if self.return_generator else list(output)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\joblib\parallel.py:1595, in Parallel._get_outputs(self, iterator, pre_dispatch)
#    1592     yield
#    1594     with self._backend.retrieval_context():
# -> 1595         yield from self._retrieve()
#    1597 except GeneratorExit:
#    1598     # The generator has been garbage collected before being fully
#    1599     # consumed. This aborts the remaining tasks if possible and warn
#    1600     # the user if necessary.
#    1601     self._exception = True
#
# File ~\AppData\Roaming\Python\Python310\site-packages\joblib\parallel.py:1707, in Parallel._retrieve(self)
#    1702 # If the next job is not ready for retrieval yet, we just wait for
#    1703 # async callbacks to progress.
#    1704 if ((len(self._jobs) == 0) or
#    1705     (self._jobs[0].get_status(
#    1706         timeout=self.timeout) == TASK_PENDING)):
# -> 1707     time.sleep(0.01)
#    1708     continue
#    1710 # We need to be careful: the job list can be filling up as
#    1711 # we empty it and Python list are not thread-safe by
#    1712 # default hence the use of the lock
#
# KeyboardInterrupt:

# %%
k = 10

# %%
knn = KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
                     metric_params=None, n_jobs=-1, n_neighbors=5, p=2,
                     weights='uniform')

# Entrenar el modelo
knn.fit(X_train_2, y_train_2)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=-1, n_neighbors=5, p=2,
#                      weights='uniform')

# %%
# Predecir con el modelo
y_pred = knn.predict(X_test_2)

# Evaluar la precisión
accuracy = accuracy_score(y_test_2, y_pred)
print(f'Precisión del modelo K-Neighbors con K={k}: {accuracy * 100:.2f}%')
# Out:
# Precisión del modelo K-Neighbors con K=10: 52.03%

# %%
from sklearn.model_selection import GridSearchCV
# Separar características (X) y el target (y)
X = df_final.drop(columns=['TIPO_GOLPE', 'JUGADOR'])
y = df_final['TIPO_GOLPE']
groups = df_final['JUGADOR']
# Definir el espacio de búsqueda de hiperparámetros
param_grid = {
    'n_neighbors': [3, 5, 7],
    'weights': ['uniform', 'distance'],
    'algorithm': ['auto', 'ball_tree', 'kd_tree', 'brute'],
    'leaf_size': [10, 20, 30],
    'p': [1, 2]  # Para la distancia de Minkowski
}
knn = KNeighborsClassifier(
    algorithm='auto',
    leaf_size=30,
    metric='minkowski',
    metric_params=None,
    n_jobs=-1,
    n_neighbors=5,
    p=2,
    weights='uniform'
)
group_kfold = GroupKFold(n_splits=6)
# Crear el objeto GridSearchCV
grid_search = GridSearchCV(estimator=knn, param_grid=param_grid, cv=group_kfold, scoring='accuracy', n_jobs=-1)

# Ejecutar la búsqueda en cuadrícula
grid_search.fit(X, y, groups=groups)

# Obtener los mejores hiperparámetros
best_params = grid_search.best_params_
print("Mejores hiperparámetros encontrados:")
print(best_params)

# Obtener la mejor puntuación
best_score = grid_search.best_score_
print("Mejor puntuación de validación cruzada:", best_score)
# Out:
# Mejores hiperparámetros encontrados:
# {'algorithm': 'auto', 'leaf_size': 10, 'n_neighbors': 3, 'p': 2, 'weights': 'distance'}
# Mejor puntuación de validación cruzada: 0.5329442007620294

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import GridSearchCV

# Definir el espacio de búsqueda de hiperparámetros
param_grid = {
    'C': [0.001, 0.01, 0.1, 1, 10, 100],  # Inverso de la fuerza de regularización
    'penalty': ['l1', 'l2'],  # Norma de penalización
    'solver': ['liblinear', 'saga']  # Algoritmo de optimización
}

# Crear el objeto de regresión logística
logistic_regression = LogisticRegression(max_iter=1000)

# Crear el objeto GridSearchCV
grid_search = GridSearchCV(estimator=logistic_regression, param_grid=param_grid, cv=group_kfold, scoring='accuracy', n_jobs=-1)

# Ejecutar la búsqueda en cuadrícula
grid_search.fit(X, y, groups=groups)

# Obtener los mejores hiperparámetros
best_params = grid_search.best_params_
print("Mejores hiperparámetros encontrados:")
print(best_params)

# Obtener la mejor puntuación
best_score = grid_search.best_score_
print("Mejor puntuación de validación cruzada:", best_score)
# Out:
# Mejores hiperparámetros encontrados:
# {'C': 1, 'penalty': 'l2', 'solver': 'saga'}
# Mejor puntuación de validación cruzada: 0.5422862082154117
# C:\Users\Holacons\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import GridSearchCV

# Definir el espacio de búsqueda de hiperparámetros
param_grid = {
    'max_depth': [3, 5, 7, 10],  # Profundidad máxima del árbol
    'min_samples_split': [2, 5, 10],  # Número mínimo de muestras requeridas para dividir un nodo interno
    'min_samples_leaf': [1, 2, 4]  # Número mínimo de muestras requeridas para ser una hoja
}

# Crear el objeto de árbol de decisión
decision_tree = DecisionTreeClassifier()

# Crear el objeto GridSearchCV
grid_search = GridSearchCV(estimator=decision_tree, param_grid=param_grid, cv=group_kfold, scoring='accuracy', n_jobs=-1)

# Ejecutar la búsqueda en cuadrícula
grid_search.fit(X, y, groups=groups)

# Obtener los mejores hiperparámetros
best_params = grid_search.best_params_
print("Mejores hiperparámetros encontrados:")
print(best_params)

# Obtener la mejor puntuación
best_score = grid_search.best_score_
print("Mejor puntuación de validación cruzada:", best_score)
# Out:
# Mejores hiperparámetros encontrados:
# {'max_depth': 10, 'min_samples_leaf': 1, 'min_samples_split': 5}
# Mejor puntuación de validación cruzada: 0.3756233118957055

# %%
# import numpy as np
# from sklearn.model_selection import GroupKFold, cross_val_score
# from sklearn.linear_model import LogisticRegression
# from sklearn.tree import DecisionTreeClassifier
# from sklearn.ensemble import RandomForestClassifier
# from sklearn.svm import SVC
# import pandas as pd

# # Separar características (X) y el target (y)
# X = df_final.drop(columns=['TIPO_GOLPE', 'JUGADOR'])
# y = df_final['TIPO_GOLPE']
# groups = df_final['JUGADOR']


# # Definir los modelos
# models = {
#     'Logistic Regression': LogisticRegression(),
#     'Decision Tree': DecisionTreeClassifier(),
#     'Random Forest': RandomForestClassifier(),
#     'SVM': SVC()
# }

# # Configurar GroupKFold
# group_kfold = GroupKFold(n_splits=6)

# # Probar y evaluar cada modelo
# for name, model in models.items():
#     cv_scores = cross_val_score(model, X, y, cv=group_kfold, groups=groups, scoring='accuracy')
#     print(f'{name}: Precisión media = {np.mean(cv_scores) * 100:.2f}%')
# Out:
# Logistic Regression: Precisión media = 67.47%
# Decision Tree: Precisión media = 48.60%
# Random Forest: Precisión media = 64.96%
# SVM: Precisión media = 74.96%

# %%
# # Separar características (X) y el target (y)
# X = df_final.drop(columns=['TIPO_GOLPE', 'JUGADOR'])
# y = df_final['TIPO_GOLPE']
# groups = df_final['JUGADOR']

# %%
# # Convertir y a números
# label_encoder = LabelEncoder()
# y = label_encoder.fit_transform(y)

# # Definir los modelos
# models = {
# #     'Logistic Regression': LogisticRegression(),
# #     'Decision Tree': DecisionTreeClassifier(),
# #     'Random Forest': RandomForestClassifier(),
# #     'SVM': SVC(),
#     'ANN': MLPClassifier(hidden_layer_sizes=(400,), max_iter=1000),
# }

# # Definir el modelo CNN
# def create_cnn():
#     cnn = Sequential([
#         Conv2D(32, (3, 3), activation='relu', input_shape=(28, 28, 1)),
#         MaxPooling2D((2, 2)),
#         Conv2D(64, (3, 3), activation='relu'),
#         MaxPooling2D((2, 2)),
#         Flatten(),
#         Dense(64, activation='relu'),
#         Dense(10, activation='softmax')
#     ])
#     cnn.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
#     return cnn

# cnn = Pipeline([('keras', KerasClassifier(build_fn=create_cnn, epochs=10, batch_size=32, verbose=0))])

# # Definir el modelo RNN
# def create_rnn():
#     rnn = Sequential([
#         SimpleRNN(64, input_shape=(10, 1)),
#         Dense(10, activation='softmax')
#     ])
#     rnn.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
#     return rnn

# rnn = Pipeline([('keras', KerasClassifier(build_fn=create_rnn, epochs=10, batch_size=32, verbose=0))])

# models['CNN'] = cnn
# models['RNN'] = rnn

# # Configurar GroupKFold
# group_kfold = GroupKFold(n_splits=6)

# # Probar y evaluar cada modelo
# for name, model in models.items():
#     cv_scores = cross_val_score(model, X, y, cv=group_kfold, groups=groups, scoring='accuracy')
#     print(f'{name}: Precisión media = {np.mean(cv_scores) * 100:.2f}%')

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV

# Definir el espacio de búsqueda de hiperparámetros
param_grid = {
    'n_estimators': [50, 100, 200],  # Número de árboles en el bosque
    'max_depth': [None, 10, 20],  # Profundidad máxima de cada árbol
    'min_samples_split': [2, 5, 10],  # Número mínimo de muestras requeridas para dividir un nodo interno
    'min_samples_leaf': [1, 2, 4]  # Número mínimo de muestras requeridas para ser una hoja
}

# Crear el objeto de Random Forest
random_forest = RandomForestClassifier()

# Crear el objeto GridSearchCV
grid_search = GridSearchCV(estimator=random_forest, param_grid=param_grid, cv=5, scoring='accuracy', n_jobs=-1)

# Ejecutar la búsqueda en cuadrícula
grid_search.fit(X, y)

# Obtener los mejores hiperparámetros
best_params = grid_search.best_params_
print("Mejores hiperparámetros encontrados:")
print(best_params)

# Obtener la mejor puntuación
best_score = grid_search.best_score_
print("Mejor puntuación de validación cruzada:", best_score)
# Out:
# Mejores hiperparámetros encontrados:
# {'max_depth': None, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 100}
# Mejor puntuación de validación cruzada: 0.5578867102396515

# %%
from sklearn.svm import SVC
from sklearn.model_selection import GridSearchCV

# Definir el espacio de búsqueda de hiperparámetros
param_grid = {
    'C': [0.1, 1, 10],  # Parámetro de regularización
    'kernel': ['linear', 'rbf'],  # Tipo de kernel
    'gamma': ['scale', 'auto']  # Coeficiente del kernel para 'rbf'
}

# Crear el objeto SVM
svm = SVC()

# Crear el objeto GridSearchCV
grid_search = GridSearchCV(estimator=svm, param_grid=param_grid, cv=5, scoring='accuracy', n_jobs=-1)

# Ejecutar la búsqueda en cuadrícula
grid_search.fit(X, y)

# Obtener los mejores hiperparámetros
best_params = grid_search.best_params_
print("Mejores hiperparámetros encontrados:")
print(best_params)

# Obtener la mejor puntuación
best_score = grid_search.best_score_
print("Mejor puntuación de validación cruzada:", best_score)
# Out:
# Mejores hiperparámetros encontrados:
# {'C': 10, 'gamma': 'scale', 'kernel': 'rbf'}
# Mejor puntuación de validación cruzada: 0.664193899782135

# %%
from sklearn.neural_network import MLPClassifier
from sklearn.model_selection import GridSearchCV

# Definir el espacio de búsqueda de hiperparámetros
param_grid = {
    'hidden_layer_sizes': [(100,), (200,), (300,)],  # Número de neuronas en la(s) capa(s) oculta(s)
    'activation': ['relu', 'tanh', 'logistic'],  # Función de activación
    'alpha': [0.0001, 0.001, 0.01]  # Término de regularización
}

# Crear el objeto de la red neuronal artificial
ann = MLPClassifier(max_iter=1000)

# Crear el objeto GridSearchCV
grid_search = GridSearchCV(estimator=ann, param_grid=param_grid, cv=5, scoring='accuracy', n_jobs=-1)

# Ejecutar la búsqueda en cuadrícula
grid_search.fit(X, y)

# Obtener los mejores hiperparámetros
best_params = grid_search.best_params_
print("Mejores hiperparámetros encontrados:")
print(best_params)

# Obtener la mejor puntuación
best_score = grid_search.best_score_
print("Mejor puntuación de validación cruzada:", best_score)
# Out:
# Mejores hiperparámetros encontrados:
# {'activation': 'tanh', 'alpha': 0.001, 'hidden_layer_sizes': (200,)}
# Mejor puntuación de validación cruzada: 0.6655119825708061

# %%
# Out:
#                 Modelo Accuracy
# 0  Logistic Regression   54,22%
# 1        Decision Tree   37,56%
# 2        Random Forest   55,78%
# 3                  SVM   66,41%
# 4                  ANN   18,54%
# 5                  KNN   53,29%
